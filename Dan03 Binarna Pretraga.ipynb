# %% [markdown]
# ## Binarna Pretraga

# %% [raw]
# procedure binarnaPretraga(lista, trazeniBroj):
#
#     start = 0
#     end = len(lista) - 1
#     mid = 0
#
#     while start <= end:
#         mid = (start + end) / 2 racunamo srednji indeks
#         if arr[mid] < trazeniBroj:
#             broj koji trazimo je u desnoj polovini
#             granica za start mid + 1
#         else if arr[mid] > trazeniBroj:
#              broj koji trazimo je u levoj polovini
#              granica za end mid - 1
#         else:
#             pronasli smo broj na mid
#     return -1
#     end while
# end procedure

# %%
def binarnaPretraga(lista, trazeniBroj): 
    start = 0 
    end = len(lista) - 1 
    srednjiIndeks = 0 

    while start <= end: 
        srednjiIndeks = (start + end) // 2 
        if lista[srednjiIndeks] < trazeniBroj: 
            start = srednjiIndeks + 1 
        elif lista[srednjiIndeks] > trazeniBroj: 
            end = srednjiIndeks - 1 
        else: 
            return srednjiIndeks 
    return -1

# %%
lista = [2,5,7,9,11,13,15,17,22,25] 
brojKojiTrazimo = 13
r = binarnaPretraga(lista, brojKojiTrazimo) 
print("Broj koji trazimo se nalazi na indeksu " , r)
# Out:
# Broj koji trazimo se nalazi na indeksu  5
